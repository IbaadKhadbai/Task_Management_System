# %%
tasks = []

def menu():
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Complete Task")

menu()
# Out:
# 1. Add Task
# 2. View Tasks
# 3. Complete Task

# %%
def add_task():
    task = input("Enter task: ")
    tasks.append(task)
    print("Task added")
